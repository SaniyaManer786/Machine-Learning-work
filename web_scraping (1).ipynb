# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'} 
webpage=requests.get('https://www.ambitionbox.com/list-of-companies?pages={}',headers=headers).text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
# print(soup.prettify())

# %%
soup.find_all('h1')[0].text
# Out:
# '\n\t\t\t\t\tTop Companies in\n\t\t\t\t \n\t\t\t\t\tINDIA\n\t\t\t\t\t'

# %%
for i in soup.find_all('h2'):
    print(i.text.strip())
# Out:
# Companies in India
# TCS
# Accenture
# Wipro
# Cognizant
# Capgemini
# HDFC Bank
# Infosys
# ICICI Bank
# HCLTech
# Tech Mahindra
# Genpact
# Teleperformance
# Jio
# Axis Bank
# Concentrix Corporation
# Amazon
# iEnergizer
# Reliance Retail
# LTIMindtree
# IBM
# Popular Collections by Industries
# Popular Collections by Cities
# Popular Collections by Roles

# %%
 soup.find_all('P', class_ ='rating')
# Out:
# []

# %%
for i in soup.find_all('p'):
  print(i.text.strip())
# Out:
# AmbitionBox
# About Company
# Discover best places to work
# Compare & find best workplace
# Bring your workplace to life
# Highlight your company's perks
# Read reviews for 6L+ companies
# Rate your former or current company
# Discover salaries for 6L+ companies
# Calculate your take home salary
# Check your market value
# Help other jobseekers
# Check your gratuity amount
# Check how much of your HRA is tax-free
# Check your salary hike
# Read interviews for 40K+ companies
# Contribute your interview questions
# AmbitionBox Employee Choice Awards - 5th Edition
# AmbitionBox Employee Choice Awards - 4th Edition
# AmbitionBox Employee Choice Awards - 3rd Edition
# Popular
# AmbitionBox Award Winner'25
# AmbitionBox Award Winner'25
# AmbitionBox Award Winner'25
# AmbitionBox Award Winner'25
# AmbitionBox Award Winner'25
# AmbitionBox Award Winner'25
# AmbitionBox Award Winner'25
# Side-by-side comparison to make informed career
# 										decisions
# Trusted by over
# ...

# %%
len(soup.find_all('p',class_='rating'))
# Out:
# 0

# %%
len(soup.find_all('a' , class_='review-count'))
# Out:
# 0

# %%
company=soup.find_all('div',class_='company_content_wrapper')

# %%
len(company)
# Out:
# 0

# %%
name=[]
rating=[]
reviews=[]
ctype=[]
hq=[]
old=[]
employees=[]

for i in company:
    name.append(i.find('h2').text.strip())
    rating.append(i.find_all('p',class_='rating').text.strip())
    reviews.append(i.find_all('a',class_='review_count').text.strip())
    ctype.append(i.find_all('p',class_='infoEntity')[0].text.strip())
    hq.append(i.find_all('a',class_='infoEntity')[0].text.strip())
    old.append(i.find_all('a',class_='infoEntity')[0].text.strip())
    employees.append(i.find_all('a',class_='infoEntity')[0].text.strip())

d={'name':name,'rating':rating,'reviews':reviews,'type':ctype,'hq':hq,'old':old,'employees':employees}
df=pd.DataFrame(d)
df
# Out:
# Empty DataFrame
# Columns: [name, rating, reviews, type, hq, old, employees]
# Index: []

# %%
df.shape
# Out:
# (0, 7)

# %%
final=pd.DataFrame()
for j in range(1,11):
    url='https://www.ambitionbox.com/list-of-companies?pages={}'.format(j)
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'} 
    webpage=requests.get(url,headers=headers).text
    soup=BeautifulSoup(webpage,'lxml')
    company=soup.find_all('div',class_='company_content_wrapper')
    name=[]
    rating=[]
    reviews=[]
    ctype=[]
    hq=[]
    old=[]
    employees=[]

    for i in company:
        name.append(i.find('h2').text.strip())
        rating.append(i.find_all('p',class_='rating').text.strip())
        reviews.append(i.find_all('a',class_='review_count').text.strip())
        ctype.append(i.find_all('p',class_='infoEntity')[0].text.strip())
        hq.append(i.find_all('a',class_='infoEntity')[0].text.strip())
        old.append(i.find_all('a',class_='infoEntity')[0].text.strip())
        try:
             employees.append(i.find_all('a',class_='infoEntity')[0].text.strip())
        except:
            employees.append(np.nan)

    d={'name':name,'rating':rating,'reviews':reviews,'type':ctype,'hq':hq,'old':old,'employees':employees}
    df=pd.DataFrame(d)
    final=final.append(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12124\3603956774.py in ?()
#      26             employees.append(np.nan)
#      27
#      28     d={'name':name,'rating':rating,'reviews':reviews,'type':ctype,'hq':hq,'old':old,'employees':employees}
#      29     df=pd.DataFrame(d)
# ---> 30     final=final.append(df)
#      31
#      32
#
# ~\OneDrive\Attachments\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
name
# Out:
# []

# %%
rating
# Out:
# []

# %%
reviews
# Out:
# []

# %%
company[0].find_all('p',class_='infoEncity')[0].text.strip()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[138], line 1
# ----> 1 company[0].find_all('p',class_='infoEncity')[0].text.strip()
#
# IndexError: list index out of range
