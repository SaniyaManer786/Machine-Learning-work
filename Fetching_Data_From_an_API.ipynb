# %%
import pandas as pd
import requests

# %%
response=requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
df=pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     32.8874
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     39.4251
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     20.0520
# 3  The true story of how businessman Oskar Schind...   1993-12-15     19.0086
# 4  The defense and the prosecution have rested an...   1957-04-10     13.4551
#
#    vote_average  vote_count
# 0         8.715       29714
# 1         8.687       22440
# 2         8.571       13581
# 3         8.567       17098
# 4         8.555        9737

# %%
df=pd.DataFrame()

# %%
all_dfs = []
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    all_dfs.append(temp_df)
df = pd.concat(all_dfs, ignore_index=True)

# %%
df
# Out:
#           id                       title  \
# 0        278    The Shawshank Redemption
# 1        238               The Godfather
# 2        240       The Godfather Part II
# 3        424            Schindler's List
# 4        389                12 Angry Men
# ...      ...                         ...
# 8555  243442  A Fantastic Back and Forth
# 8556   13279            Lakeview Terrace
# 8557   10678     Bringing Down the House
# 8558    9348                     Species
# 8559  301348               Elvis & Nixon
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# 8555  Middle-aged family man Arnaldo is kicked out b...   2013-12-12
# 8556  A young interracial couple has just moved into...   2008-09-19
# 8557  Uptight lawyer Peter Sanderson wants to dive b...   2003-03-07
# 8558  In 1993, the Search for Extra Terrestrial Inte...   1995-07-07
# 8559  In 1970, a few days before Christmas, Elvis Pr...   2016-03-22
#
#       popularity  vote_average  vote_count
# 0        32.8874         8.715       29714
# 1        39.4251         8.687       22440
# 2        20.0520         8.571       13581
# 3        19.0086         8.567       17098
# 4        13.4551         8.555        9737
# ...          ...           ...         ...
# 8555      0.4420         5.975         323
# 8556      2.9480         5.975        1129
# 8557      1.1880         5.975         729
# 8558      4.7946         6.000        1791
# 8559      2.0651         5.974         437
#
# [8560 rows x 7 columns]

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('Movies.csv', index=False)
